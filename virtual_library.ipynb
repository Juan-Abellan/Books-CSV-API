# %% [markdown]
# # Virtual_library

# %% [markdown]
# ## imports

# %%
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load books from CSV

# %%
books_df = pd.read_csv('data/books.csv', on_bad_lines='skip')
books_df = books_df.drop(columns=['bookID', 'isbn', 'average_rating', 'language_code', 'ratings_count', 'text_reviews_count'])
display(books_df.head())
books_df.info()
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors         isbn13    num_pages publication_date  \
# 0  J.K. Rowling/Mary GrandPré  9780439785969          652        9/16/2006
# 1  J.K. Rowling/Mary GrandPré  9780439358071          870         9/1/2004
# 2                J.K. Rowling  9780439554893          352        11/1/2003
# 3  J.K. Rowling/Mary GrandPré  9780439655484          435         5/1/2004
# 4  J.K. Rowling/Mary GrandPré  9780439682589         2690        9/13/2004
#
#          publisher
# 0  Scholastic Inc.
# 1  Scholastic Inc.
# 2       Scholastic
# 3  Scholastic Inc.
# 4       Scholastic
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             11123 non-null  object
#  1   authors           11123 non-null  object
#  2   isbn13            11123 non-null  int64
#  3     num_pages       11123 non-null  int64
#  4   publication_date  11123 non-null  object
#  5   publisher         11123 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 521.5+ KB

# %% [markdown]
# ## Changing publication_date column to datetime format

# %%
books_df["publication_date"] = pd.to_datetime(
                                                books_df["publication_date"],
                                                format="%f/%M/%Y"
                                                )
books_df.dtypes
# Out:
# title                       object
# authors                     object
# isbn13                       int64
#   num_pages                  int64
# publication_date    datetime64[ns]
# publisher                   object
# dtype: object

# %% [markdown]
# ## Creating a URL column

# %%
books_df['cover_url'] = None
books_df.head()
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors         isbn13    num_pages  \
# 0  J.K. Rowling/Mary GrandPré  9780439785969          652
# 1  J.K. Rowling/Mary GrandPré  9780439358071          870
# 2                J.K. Rowling  9780439554893          352
# 3  J.K. Rowling/Mary GrandPré  9780439655484          435
# 4  J.K. Rowling/Mary GrandPré  9780439682589         2690
#
#          publication_date        publisher cover_url
# 0 2006-01-01 00:16:00.900  Scholastic Inc.      None
# 1 2004-01-01 00:01:00.900  Scholastic Inc.      None
# 2 2003-01-01 00:01:00.110       Scholastic      None
# 3 2004-01-01 00:01:00.500  Scholastic Inc.      None
# 4 2004-01-01 00:13:00.900       Scholastic      None

# %% [markdown]
# ## API - Open Library

# %%
def fetch_book(isbn):
    url = 'https://openlibrary.org/api/books'
    
    params = {
            'bibkeys': f'ISBN:{isbn}',
            'format': 'json',
            'jscmd': 'data'
            }
    
    response = requests.get(url, params=params).json()
    
    # Check whether ISBN is in the response
    if f'ISBN:{isbn}' in response:
        return response[f'ISBN:{isbn}']
    else:
        return ''
    
# fetch_book(isbn="9780439655484")

# %%
# %%time

for index, row in books_df.head(20).iterrows():
    if row['cover_url'] is None:
        isbn = row['isbn13']
        print(f"Fetching cover for {row['title']}")      
        book = fetch_book(isbn)
        if book:
            cover_url = book.get('cover', {}).get('large', '')
            books_df.loc[index, 'cover_url'] = cover_url
        else:
            books_df.loc[index, 'cover_url'] = ''
# Out:
# Fetching cover for Harry Potter and the Half-Blood Prince (Harry Potter  #6)
# Fetching cover for Harry Potter and the Order of the Phoenix (Harry Potter  #5)
# Fetching cover for Harry Potter and the Chamber of Secrets (Harry Potter  #2)
# Fetching cover for Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)
# Fetching cover for Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)
# Fetching cover for Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation
# Fetching cover for Harry Potter Collection (Harry Potter  #1-6)
# Fetching cover for The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5)
# Fetching cover for The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)
# Fetching cover for The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)
# Fetching cover for The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)
# Fetching cover for The Ultimate Hitchhiker's Guide (Hitchhiker's Guide to the Galaxy  #1-5)
# Fetching cover for A Short History of Nearly Everything
# Fetching cover for Bill Bryson's African Diary
# Fetching cover for Bryson's Dictionary of Troublesome Words: A Writer's Guide to Getting It Right
# Fetching cover for In a Sunburned Country
# Fetching cover for I'm a Stranger Here Myself: Notes on Returning to America After Twenty Years Away
# Fetching cover for The Lost Continent: Travels in Small Town America
# Fetching cover for Neither Here nor There: Travels in Europe
# Fetching cover for Notes from a Small Island
# CPU times: user 7.66 s, sys: 64 ms, total: 7.73 s
# Wall time: 21.4 s

# %%
books_df.columns
# Out:
# Index(['title', 'authors', 'isbn13', '  num_pages', 'publication_date',
#        'publisher', 'cover_url'],
#       dtype='object')

# %%
books_df.index += 1
books_df
# Out:
#                                                    title  \
# 1      Harry Potter and the Half-Blood Prince (Harry ...
# 2      Harry Potter and the Order of the Phoenix (Har...
# 3      Harry Potter and the Chamber of Secrets (Harry...
# 4      Harry Potter and the Prisoner of Azkaban (Harr...
# 5      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                  ...
# 11119   Expelled from Eden: A William T. Vollmann Reader
# 11120                        You Bright and Risen Angels
# 11121                    The Ice-Shirt (Seven Dreams #1)
# 11122                                        Poor People
# 11123                        Las aventuras de Tom Sawyer
#
#                                                  authors         isbn13  \
# 1                             J.K. Rowling/Mary GrandPré  9780439785969
# 2                             J.K. Rowling/Mary GrandPré  9780439358071
# 3                                           J.K. Rowling  9780439554893
# 4                             J.K. Rowling/Mary GrandPré  9780439655484
# 5                             J.K. Rowling/Mary GrandPré  9780439682589
# ...                                                  ...            ...
# 11119  William T. Vollmann/Larry McCaffery/Michael He...  9781560254416
# 11120                                William T. Vollmann  9780140110876
# 11121                                William T. Vollmann  9780140131963
# 11122                                William T. Vollmann  9780060878825
# 11123                                         Mark Twain  9788497646987
#
#          num_pages        publication_date        publisher  \
# 1              652 2006-01-01 00:16:00.900  Scholastic Inc.
# 2              870 2004-01-01 00:01:00.900  Scholastic Inc.
# 3              352 2003-01-01 00:01:00.110       Scholastic
# 4              435 2004-01-01 00:01:00.500  Scholastic Inc.
# 5             2690 2004-01-01 00:13:00.900       Scholastic
# ...            ...                     ...              ...
# 11119          512 2004-01-01 00:21:00.120    Da Capo Press
# 11120          635 1988-01-01 00:01:00.120    Penguin Books
# 11121          415 1993-01-01 00:01:00.800    Penguin Books
# 11122          434 2007-01-01 00:27:00.200             Ecco
# 11123          272 2006-01-01 00:28:00.500    Edimat Libros
#
#                                                cover_url
# 1      https://covers.openlibrary.org/b/id/9326654-L.jpg
# 2      https://covers.openlibrary.org/b/id/12025650-L...
# 3      https://covers.openlibrary.org/b/id/10301720-L...
# 4      https://covers.openlibrary.org/b/id/8778528-L.jpg
# 5       https://covers.openlibrary.org/b/id/278981-L.jpg
# ...                                                  ...
# 11119                                               None
# 11120                                               None
# 11121                                               None
# 11122                                               None
# 11123                                               None
#
# [11123 rows x 7 columns]

# %% [markdown]
# ## Calling the API with multiple ISBNs at a time

# %%
isbns = [9780439785969, 9780439358071, 9780439554930]
[f"ISBN:{isbn}" for isbn in isbns]
# Out:
# ['ISBN:9780439785969', 'ISBN:9780439358071', 'ISBN:9780439554930']

# %%
",".join([f"ISBN:{isbn}" for isbn in isbns])
# Out:
# 'ISBN:9780439785969,ISBN:9780439358071,ISBN:9780439554930'

# %%
def fetch_books(isbns):
    url = "https://openlibrary.org/api/books"
    bibkeys = ",".join([f"ISBN:{isbn}" for isbn in isbns])
    
    params = {
        'bibkeys': bibkeys,
        'format': 'json',
        'jscmd': 'data'
    }
    
    response = requests.get(url, params=params).json()
    
    return response

fetch_books(isbns='ISBN:9780439785969,ISBN:9780439358071,ISBN:9780439554930')
# Out:
# {'ISBN:9': {'url': 'https://openlibrary.org/books/OL31367271M/Novel_Districts',
#   'key': '/books/OL31367271M',
#   'title': 'Novel Districts',
#   'subtitle': 'Critical Readings of Monika Fagerholm',
#   'authors': [{'url': 'https://openlibrary.org/authors/OL8908091A/Mia_Österlund',
#     'name': 'Mia Österlund'}],
#   'number_of_pages': 262,
#   'pagination': '1 electronic resource (262 p.)',
#   'identifiers': {'isbn_10': ['9'],
#    'isbn_13': ['9789522227942', '9789522227959'],
#    'openlibrary': ['OL31367271M']},
#   'publishers': [{'name': 'Finnish Literature Society / SKS'}],
#   'publish_places': [{'name': 'Helsinki'}],
#   'publish_date': '2016',
#   'subjects': [{'name': 'Scandinavia Northern Europe',
#     'url': 'https://openlibrary.org/subjects/scandinavia_northern_europe'},
#    {'name': 'Finland', 'url': 'https://openlibrary.org/subjects/finland'},
#    {'name': 'Literary studies: fiction, novelists & prose writers',
#     'url': 'https://openlibrary.org/subjects/literary_studies:_fiction,_novelists_&_prose_writers'},
#    {'name': 'Linguistics',
#     'url': 'https://openlibrary.org/subjects/linguistics'},
#    {'name': 'CFB', 'url': 'https://openlibrary.org/subjects/cfb'},
#    {'name': 'CF', 'url': 'https://openlibrary.org/subjects/cf'},
#    {'name': 'Sociolinguistics',
#     'url': 'https://openlibrary.org/subjects/sociolinguistics'},
#    {'name': 'Institutions & learned societies: general',
#     'url': 'https://openlibrary.org/subjects/institutions_&_learned_societies:_general'},
#    {'name': 'Higher & further education, tertiary education',
#     'url': 'https://openlibrary.org/subjects/higher_&_further_education,_tertiary_education'},
#    {'name': 'Philosophy & theory of education',
#     'url': 'https://openlibrary.org/subjects/philosophy_&_theory_of_education'},
#    {'name': 'Social & cultural history',
#     'url': 'https://openlibrary.org/subjects/social_&_cultural_history'},
#    {'name': 'History of education',
#     'url': 'https://openlibrary.org/subjects/history_of_education'},
#    {'name': 'British & Irish history',
#     'url': 'https://openlibrary.org/subjects/british_&_irish_history'},
#    {'name': 'History', 'url': 'https://openlibrary.org/subjects/history'}],
#   'notes': 'Open Access Unrestricted online access\n\nJane and Aatos Erkko Foundation grant and SKS\n\nCreative Commons https://creativecommons.org/licenses/by-nc-nd/4.0/\n\nEnglish'},
#  'ISBN:7': {'url': 'https://openlibrary.org/books/OL31370422M/The_Education_of_the_Eye',
#   'key': '/books/OL31370422M',
#   'title': 'The Education of the Eye',
#   'subtitle': 'History of the Royal Polytechnic Institution 1838-1881',
#   'authors': [{'url': 'https://openlibrary.org/authors/OL8011035A/Brenda_Weeden',
#     'name': 'Brenda Weeden'}],
#   'number_of_pages': 110,
#   'pagination': '1 electronic resource (110 p.)',
#   'identifiers': {'isbn_10': ['7'], 'openlibrary': ['OL31370422M']},
#   'publishers': [{'name': 'University of Westminster Press'}],
#   'publish_places': [{'name': 'London'}],
#   'publish_date': '2008',
#   'subjects': [{'name': 'Institutions & learned societies: general',
#     'url': 'https://openlibrary.org/subjects/institutions_&_learned_societies:_general'},
#    {'name': 'Higher & further education, tertiary education',
#     'url': 'https://openlibrary.org/subjects/higher_&_further_education,_tertiary_education'},
#    {'name': 'Social & cultural history',
#     'url': 'https://openlibrary.org/subjects/social_&_cultural_history'},
#    {'name': 'Impact of science & technology on society',
#     'url': 'https://openlibrary.org/subjects/impact_of_science_&_technology_on_society'},
#    {'name': 'History of education',
#     'url': 'https://openlibrary.org/subjects/history_of_education'},
#    {'name': 'History of science',
#     'url': 'https://openlibrary.org/subjects/history_of_science'},
#    {'name': 'Legal history',
#     'url': 'https://openlibrary.org/subjects/legal_history'},
#    {'name': 'European history',
#     'url': 'https://openlibrary.org/subjects/european_history'},
#    {'name': 'History of the Americas',
#     'url': 'https://openlibrary.org/subjects/history_of_the_americas'},
#    {'name': 'Computer programming / software development',
#     'url': 'https://openlibrary.org/subjects/computer_programming_/_software_development'},
#    {'name': 'Gender studies: women',
#     'url': 'https://openlibrary.org/subjects/gender_studies:_women'},
#    {'name': 'Popular culture',
#     'url': 'https://openlibrary.org/subjects/popular_culture'},
#    {'name': 'Finland', 'url': 'https://openlibrary.org/subjects/finland'},
#    {'name': 'Film: styles & genres',
#     'url': 'https://openlibrary.org/subjects/film:_styles_&_genres'},
#    {'name': 'Gender studies: men',
#     'url': 'https://openlibrary.org/subjects/gender_studies:_men'},
#    {'name': 'History', 'url': 'https://openlibrary.org/subjects/history'},
#    {'name': 'Universities and colleges',
#     'url': 'https://openlibrary.org/subjects/universities_and_colleges'},
#    {'name': 'Royal Polytechnic Institution (London, England)',
#     'url': 'https://openlibrary.org/subjects/royal_polytechnic_institution_(london,_england)'}],
#   'notes': 'Open Access Unrestricted online access\n\nCreative Commons by-nc-nd/4.0/\n\nEnglish'},
#  'ISBN:8': {'url': "https://openlibrary.org/books/OL31371504M/L'eterno_ritorno_del_Droit_des_gens_di_Emer_de_Vattel",
#   'key': '/books/OL31371504M',
#   'title': "L'eterno ritorno del Droit des gens di Emer de Vattel",
#   'subtitle': "L'impatto sulla cultura giuridica in prospettiva globale",
#   'authors': [{'url': 'https://openlibrary.org/authors/OL8908760A/Elisabetta_Fiocchi_Malaspina',
#     'name': 'Elisabetta Fiocchi Malaspina'}],
#   'number_of_pages': 364,
#   'pagination': '1 electronic resource (364 p.)',
#   'identifiers': {'isbn_10': ['8'],
#    'isbn_13': ['9783944773179'],
#    'openlibrary': ['OL31371504M']},
#   'publishers': [{'name': 'Max Planck Institute for European Legal History'}],
#   'publish_places': [{'name': 'Frankfurt am Main'}],
#   'publish_date': '2017',
#   'subjects': [{'name': 'Legal history',
#     'url': 'https://openlibrary.org/subjects/legal_history'},
#    {'name': 'International law reports',
#     'url': 'https://openlibrary.org/subjects/international_law_reports'},
#    {'name': 'Universities',
#     'url': 'https://openlibrary.org/subjects/universities'},
#    {'name': 'Social & cultural history',
#     'url': 'https://openlibrary.org/subjects/social_&_cultural_history'},
#    {'name': 'Institutions & learned societies: general',
#     'url': 'https://openlibrary.org/subjects/institutions_&_learned_societies:_general'},
#    {'name': 'History of education',
#     'url': 'https://openlibrary.org/subjects/history_of_education'},
#    {'name': 'Higher & further education, tertiary education',
#     'url': 'https://openlibrary.org/subjects/higher_&_further_education,_tertiary_education'},
#    {'name': 'Language', 'url': 'https://openlibrary.org/subjects/language'},
#    {'name': 'Microeconomics',
#     'url': 'https://openlibrary.org/subjects/microeconomics'},
#    {'name': 'China', 'url': 'https://openlibrary.org/subjects/china'},
#    {'name': 'Swedish', 'url': 'https://openlibrary.org/subjects/swedish'},
#    {'name': 'Sociology: customs & traditions',
#     'url': 'https://openlibrary.org/subjects/sociology:_customs_&_traditions'},
#    {'name': 'Religion: general',
#     'url': 'https://openlibrary.org/subjects/religion:_general'},
#    {'name': 'Folklore, myths & legends',
#     'url': 'https://openlibrary.org/subjects/folklore,_myths_&_legends'},
#    {'name': 'Finland', 'url': 'https://openlibrary.org/subjects/finland'},
#    {'name': 'Poetry', 'url': 'https://openlibrary.org/subjects/poetry'}],
#   'notes': 'Open Access Unrestricted online access\n\nCreative Commons https://creativecommons.org/licenses/by-nc-nd/3.0/de/\n\nItalian'},
#  'ISBN:0': {'url': 'https://openlibrary.org/books/OL26468254M/All_We_Ever_Wanted_A_Novel',
#   'key': '/books/OL26468254M',
#   'title': 'All We Ever Wanted: A Novel',
#   'authors': [{'url': 'https://openlibrary.org/authors/OL3503714A/Emily_Giffin',
#     'name': 'Emily Giffin'}],
#   'identifiers': {'isbn_10': ['0'], 'openlibrary': ['OL26468254M']},
#   'publishers': [{'name': ''}]},
#  'ISBN:4': {'url': 'https://openlibrary.org/books/OL26196076M/Bayangan_Katarsis',
#   'key': '/books/OL26196076M',
#   'title': 'Bayangan Katarsis',
#   'authors': [{'url': 'https://openlibrary.org/authors/OL7359256A/Tuan_Noorkorina_Tuan_Kub',
#     'name': 'Tuan Noorkorina Tuan Kub'}],
#   'number_of_pages': 584,
#   'identifiers': {'isbn_13': ['4'], 'openlibrary': ['OL26196076M']},
#   'publishers': [{'name': 'Dewan Bahasa dan Pustaka, Malaysia'}],
#   'publish_places': [{'name': 'Malaysia'}],
#   'publish_date': '2015',
#   'subjects': [{'name': 'Public health & preventive medicine',
#     'url': 'https://openlibrary.org/subjects/public_health_&_preventive_medicine'},
#    {'name': 'Literature & literary studies',
#     'url': 'https://openlibrary.org/subjects/literature_&_literary_studies'},
#    {'name': 'Society & social sciences',
#     'url': 'https://openlibrary.org/subjects/society_&_social_sciences'},
#    {'name': 'Education', 'url': 'https://openlibrary.org/subjects/education'},
#    {'name': 'Philosophy & theory of education',
#     'url': 'https://openlibrary.org/subjects/philosophy_&_theory_of_education'},
#    {'name': 'Communication studies',
#     'url': 'https://openlibrary.org/subjects/communication_studies'},
#    {'name': 'Educational: Social sciences',
#     'url': 'https://openlibrary.org/subjects/educational:_social_sciences'},
#    {'name': 'Media studies',
#     'url': 'https://openlibrary.org/subjects/media_studies'},
#    {'name': 'Literary studies: general',
#     'url': 'https://openlibrary.org/subjects/literary_studies:_general'},
#    {'name': 'Literary studies: fiction, novelists & prose writers',
#     'url': 'https://openlibrary.org/subjects/literary_studies:_fiction,_novelists_&_prose_writers'},
#    {'name': 'Literary theory',
#     'url': 'https://openlibrary.org/subjects/literary_theory'}],
#   'links': [{'title': 'Laman Web Dewan Bahasa & Pustaka',
#     'url': 'https://bukudbp.com/collections/novel-cerpen-drama/products/bayangan-katarsis'}],
#   'cover': {'small': 'https://covers.openlibrary.org/b/id/7880051-S.jpg',
#    'medium': 'https://covers.openlibrary.org/b/id/7880051-M.jpg',
#    'large': 'https://covers.openlibrary.org/b/id/7880051-L.jpg'}},
#  'ISBN:3': {'url': 'https://openlibrary.org/books/OL25679436M/Chemistry_Class_1st_Year_Book',
#   'key': '/books/OL25679436M',
#   'title': 'Chemistry Class 1st Year Book',
#   'authors': [{'url': 'https://openlibrary.org/authors/OL7238397A/Dr.Taj_Mahmood_Rana',
#     'name': 'Dr.Taj Mahmood Rana'}],
#   'identifiers': {'isbn_10': ['3'], 'openlibrary': ['OL25679436M']},
#   'publishers': [{'name': 'National Book Foundation Islamabad'}],
#   'publish_date': '2014',
#   'subjects': [{'name': 'The arts',
#     'url': 'https://openlibrary.org/subjects/the_arts'},
#    {'name': 'Film, TV & radio',
#     'url': 'https://openlibrary.org/subjects/film,_tv_&_radio'},
#    {'name': 'Film theory & criticism',
#     'url': 'https://openlibrary.org/subjects/film_theory_&_criticism'},
#    {'name': 'Films, cinema',
#     'url': 'https://openlibrary.org/subjects/films,_cinema'},
#    {'name': 'Computing & information technology',
#     'url': 'https://openlibrary.org/subjects/computing_&_information_technology'},
#    {'name': 'Information visualization',
#     'url': 'https://openlibrary.org/subjects/information_visualization'},
#    {'name': 'Human-computer interaction',
#     'url': 'https://openlibrary.org/subjects/human-computer_interaction'},
#    {'name': 'User interface design & usability',
#     'url': 'https://openlibrary.org/subjects/user_interface_design_&_usability'},
#    {'name': 'Information architecture',
#     'url': 'https://openlibrary.org/subjects/information_architecture'},
#    {'name': 'Computer science',
#     'url': 'https://openlibrary.org/subjects/computer_science'},
#    {'name': 'Literary studies: general',
#     'url': 'https://openlibrary.org/subjects/literary_studies:_general'},
#    {'name': 'Literary studies: c 1800 to c 1900',
#     'url': 'https://openlibrary.org/subjects/literary_studies:_c_1800_to_c_1900'},
#    {'name': 'Poetry by individual poets',
#     'url': 'https://openlibrary.org/subjects/poetry_by_individual_poets'},
#    {'name': 'Literature & literary studies',
#     'url': 'https://openlibrary.org/subjects/literature_&_literary_studies'}],
#   'cover': {'small': 'https://covers.openlibrary.org/b/id/7348653-S.jpg',
#    'medium': 'https://covers.openlibrary.org/b/id/7348653-M.jpg',
#    'large': 'https://covers.openlibrary.org/b/id/7348653-L.jpg'}},
#  'ISBN:5': {'url': 'https://openlibrary.org/books/OL31366776M/Lokale_Agenda_für_globale_Probleme_Zur_Entwicklung_und_Umsetzung_von_Nachhaltigkeitsstrategien_aus_i',
#   'key': '/books/OL31366776M',
#   'title': 'Lokale Agenda für globale Probleme? Zur Entwicklung und Umsetzung von Nachhaltigkeitsstrategien aus institutionenökonomischer Sicht',
#   'authors': [{'url': 'https://openlibrary.org/authors/OL8908016A/Sandra_Greiner',
#     'name': 'Sandra Greiner'}],
#   'number_of_pages': 221,
#   'pagination': '1 electronic resource (221 p.)',
#   'identifiers': {'isbn_10': ['5'], 'openlibrary': ['OL31366776M']},
#   'publishers': [{'name': 'Hamburg University Press'}],
#   'publish_places': [{'name': 'Hamburg'}],
#   'publish_date': '2002',
#   'subjects': [{'name': 'The environment',
#     'url': 'https://openlibrary.org/subjects/the_environment'},
#    {'name': 'Literary studies: from c 1900 -',
#     'url': 'https://openlibrary.org/subjects/literary_studies:_from_c_1900_-'},
#    {'name': 'Poetry', 'url': 'https://openlibrary.org/subjects/poetry'},
#    {'name': 'Social & cultural history',
#     'url': 'https://openlibrary.org/subjects/social_&_cultural_history'},
#    {'name': 'Film theory & criticism',
#     'url': 'https://openlibrary.org/subjects/film_theory_&_criticism'},
#    {'name': 'Political control & freedoms',
#     'url': 'https://openlibrary.org/subjects/political_control_&_freedoms'},
#    {'name': 'Modern history to 20th century: c 1700 to c 1900',
#     'url': 'https://openlibrary.org/subjects/modern_history_to_20th_century:_c_1700_to_c_1900'},
#    {'name': 'Sociology: death & dying',
#     'url': 'https://openlibrary.org/subjects/sociology:_death_&_dying'},
#    {'name': 'Boer Wars', 'url': 'https://openlibrary.org/subjects/boer_wars'},
#    {'name': 'Caribbean islands',
#     'url': 'https://openlibrary.org/subjects/caribbean_islands'},
#    {'name': 'Films, cinema',
#     'url': 'https://openlibrary.org/subjects/films,_cinema'},
#    {'name': 'History of the Americas',
#     'url': 'https://openlibrary.org/subjects/history_of_the_americas'},
#    {'name': 'Diplomacy', 'url': 'https://openlibrary.org/subjects/diplomacy'},
#    {'name': 'Social & cultural anthropology, ethnography',
#     'url': 'https://openlibrary.org/subjects/social_&_cultural_anthropology,_ethnography'},
#    {'name': 'Sociolinguistics',
#     'url': 'https://openlibrary.org/subjects/sociolinguistics'},
#    {'name': 'Linguistics',
#     'url': 'https://openlibrary.org/subjects/linguistics'}],
#   'notes': 'Open Access Unrestricted online access\n\nAll rights reserved\n\nGerman'},
#  'ISBN:6': {'url': 'https://openlibrary.org/books/OL31367817M/Eating_Identities',
#   'key': '/books/OL31367817M',
#   'title': 'Eating Identities',
#   'subtitle': 'Reading Food in Asian American Literature',
#   'authors': [{'url': 'https://openlibrary.org/authors/OL1516965A/Wenying_Xu',
#     'name': 'Wenying Xu'}],
#   'identifiers': {'isbn_10': ['6'],
#    'isbn_13': ['9780824878436'],
#    'openlibrary': ['OL31367817M']},
#   'publishers': [{'name': "University of Hawai'i Press"}],
#   'publish_places': [{'name': 'Honolulu'}],
#   'publish_date': '20071113',
#   'subjects': [{'name': 'American literature',
#     'url': 'https://openlibrary.org/subjects/american_literature'},
#    {'name': 'Asian American authors',
#     'url': 'https://openlibrary.org/subjects/asian_american_authors'},
#    {'name': 'Asian Americans',
#     'url': 'https://openlibrary.org/subjects/asian_americans'},
#    {'name': 'Asian Americans in literature',
#     'url': 'https://openlibrary.org/subjects/asian_americans_in_literature'},
#    {'name': 'Cookery in literature',
#     'url': 'https://openlibrary.org/subjects/cookery_in_literature'},
#    {'name': 'Dinners and dining in literature',
#     'url': 'https://openlibrary.org/subjects/dinners_and_dining_in_literature'},
#    {'name': 'Food habits',
#     'url': 'https://openlibrary.org/subjects/food_habits'},
#    {'name': 'Food habits in literature',
#     'url': 'https://openlibrary.org/subjects/food_habits_in_literature'},
#    {'name': 'Gastronomy in literature',
#     'url': 'https://openlibrary.org/subjects/gastronomy_in_literature'},
#    {'name': 'History and criticism',
#     'url': 'https://openlibrary.org/subjects/history_and_criticism'},
#    {'name': 'Intellectual life',
#     'url': 'https://openlibrary.org/subjects/intellectual_life'},
#    {'name': 'Social aspects of Food habits',
#     'url': 'https://openlibrary.org/subjects/social_aspects_of_food_habits'},
#    {'name': 'American literature -- Asian American authors -- History and criticism',
#     'url': 'https://openlibrary.org/subjects/american_literature_--_asian_american_authors_--_history_and_criticism'},
#    {'name': 'Asian Americans -- Intellectual life',
#     'url': 'https://openlibrary.org/subjects/asian_americans_--_intellectual_life'},
#    {'name': 'Food habits -- Social aspects',
#     'url': 'https://openlibrary.org/subjects/food_habits_--_social_aspects'},
#    {'name': 'American literature, asian american authors, history and criticism',
#     'url': 'https://openlibrary.org/subjects/american_literature,_asian_american_authors,_history_and_criticism'},
#    {'name': 'Asian americans in literature',
#     'url': 'https://openlibrary.org/subjects/asian_americans_in_literature'},
#    {'name': 'Cooking in literature',
#     'url': 'https://openlibrary.org/subjects/cooking_in_literature'},
#    {'name': 'History', 'url': 'https://openlibrary.org/subjects/history'},
#    {'name': 'Literary studies: c 1500 to c 1800',
#     'url': 'https://openlibrary.org/subjects/literary_studies:_c_1500_to_c_1800'},
#    {'name': 'Social aspects',
#     'url': 'https://openlibrary.org/subjects/social_aspects'}],
#   'notes': 'Open Access Unrestricted online access\n\nKnowledge Unlatched\n\nCreative Commons https://creativecommons.org/licenses/by-nc-nd/4.0/legalcode\n\nEnglish'},
#  'ISBN:1': {'url': 'https://openlibrary.org/books/OL24620058M/A_French_Restoration',
#   'key': '/books/OL24620058M',
#   'title': 'A French Restoration',
#   'authors': [{'url': 'https://openlibrary.org/authors/OL3149433A/Clive_Kristen',
#     'name': 'Clive Kristen'}],
#   'identifiers': {'isbn_10': ['1'], 'openlibrary': ['OL24620058M']},
#   'publishers': [{'name': 'How To  Books'}],
#   'publish_date': '2006',
#   'subjects': [{'name': 'Linguistics',
#     'url': 'https://openlibrary.org/subjects/linguistics'},
#    {'name': 'Sociolinguistics',
#     'url': 'https://openlibrary.org/subjects/sociolinguistics'},
#    {'name': 'The arts: general issues',
#     'url': 'https://openlibrary.org/subjects/the_arts:_general_issues'},
#    {'name': 'Film theory & criticism',
#     'url': 'https://openlibrary.org/subjects/film_theory_&_criticism'},
#    {'name': 'Electronic, holographic & video art',
#     'url': 'https://openlibrary.org/subjects/electronic,_holographic_&_video_art'},
#    {'name': 'Gender studies, gender groups',
#     'url': 'https://openlibrary.org/subjects/gender_studies,_gender_groups'},
#    {'name': 'Animals & society',
#     'url': 'https://openlibrary.org/subjects/animals_&_society'},
#    {'name': 'Literary studies: fiction, novelists & prose writers',
#     'url': 'https://openlibrary.org/subjects/literary_studies:_fiction,_novelists_&_prose_writers'},
#    {'name': 'Literature: history & criticism',
#     'url': 'https://openlibrary.org/subjects/literature:_history_&_criticism'},
#    {'name': 'Literature & literary studies',
#     'url': 'https://openlibrary.org/subjects/literature_&_literary_studies'},
#    {'name': 'Popular philosophy',
#     'url': 'https://openlibrary.org/subjects/popular_philosophy'},
#    {'name': 'Cultural studies',
#     'url': 'https://openlibrary.org/subjects/cultural_studies'},
#    {'name': 'Semiotics / semiology',
#     'url': 'https://openlibrary.org/subjects/semiotics_/_semiology'},
#    {'name': 'Popular culture',
#     'url': 'https://openlibrary.org/subjects/popular_culture'},
#    {'name': 'Alternative belief systems',
#     'url': 'https://openlibrary.org/subjects/alternative_belief_systems'},
#    {'name': 'Social & political philosophy',
#     'url': 'https://openlibrary.org/subjects/social_&_political_philosophy'},
#    {'name': 'Economic theory & philosophy',
#     'url': 'https://openlibrary.org/subjects/economic_theory_&_philosophy'},
#    {'name': 'Economic systems & structures',
#     'url': 'https://openlibrary.org/subjects/economic_systems_&_structures'},
#    {'name': 'Sociology', 'url': 'https://openlibrary.org/subjects/sociology'},
#    {'name': 'Political economy',
#     'url': 'https://openlibrary.org/subjects/political_economy'},
#    {'name': 'Archaeology',
#     'url': 'https://openlibrary.org/subjects/archaeology'},
#    {'name': 'Medieval history',
#     'url': 'https://openlibrary.org/subjects/medieval_history'},
#    {'name': 'Art treatments & subjects',
#     'url': 'https://openlibrary.org/subjects/art_treatments_&_subjects'},
#    {'name': 'China', 'url': 'https://openlibrary.org/subjects/china'},
#    {'name': 'Industrial / commercial art & design',
#     'url': 'https://openlibrary.org/subjects/industrial_/_commercial_art_&_design'},
#    {'name': 'Islamic life & practice',
#     'url': 'https://openlibrary.org/subjects/islamic_life_&_practice'},
#    {'name': 'Music', 'url': 'https://openlibrary.org/subjects/music'},
#    {'name': 'Nursing & ancillary services',
#     'url': 'https://openlibrary.org/subjects/nursing_&_ancillary_services'},
#    {'name': 'Industrial relations & trade unions law',
#     'url': 'https://openlibrary.org/subjects/industrial_relations_&_trade_unions_law'},
#    {'name': 'Employment contracts',
#     'url': 'https://openlibrary.org/subjects/employment_contracts'},
#    {'name': 'Legal history',
#     'url': 'https://openlibrary.org/subjects/legal_history'},
#    {'name': 'General & world history',
#     'url': 'https://openlibrary.org/subjects/general_&_world_history'},
#    {'name': 'Great Britain United Kingdom',
#     'url': 'https://openlibrary.org/subjects/great_britain_united_kingdom'},
#    {'name': 'Constitution: government & the state',
#     'url': 'https://openlibrary.org/subjects/constitution:_government_&_the_state'},
#    {'name': 'Political parties',
#     'url': 'https://openlibrary.org/subjects/political_parties'},
#    {'name': 'Politics & government',
#     'url': 'https://openlibrary.org/subjects/politics_&_government'},
#    {'name': 'Political structures: democracy',
#     'url': 'https://openlibrary.org/subjects/political_structures:_democracy'},
#    {'name': 'Theatre studies',
#     'url': 'https://openlibrary.org/subjects/theatre_studies'},
#    {'name': 'Film, TV & radio',
#     'url': 'https://openlibrary.org/subjects/film,_tv_&_radio'},
#    {'name': 'Communication studies',
#     'url': 'https://openlibrary.org/subjects/communication_studies'},
#    {'name': 'Philosophy',
#     'url': 'https://openlibrary.org/subjects/philosophy'},
#    {'name': 'Media studies',
#     'url': 'https://openlibrary.org/subjects/media_studies'},
#    {'name': 'Poetry by individual poets',
#     'url': 'https://openlibrary.org/subjects/poetry_by_individual_poets'},
#    {'name': 'Poetry', 'url': 'https://openlibrary.org/subjects/poetry'},
#    {'name': 'Society & culture: general',
#     'url': 'https://openlibrary.org/subjects/society_&_culture:_general'},
#    {'name': 'Industrial or vocational training',
#     'url': 'https://openlibrary.org/subjects/industrial_or_vocational_training'},
#    {'name': 'Teaching skills & techniques',
#     'url': 'https://openlibrary.org/subjects/teaching_skills_&_techniques'},
#    {'name': 'Adult education, continuous learning',
#     'url': 'https://openlibrary.org/subjects/adult_education,_continuous_learning'},
#    {'name': 'Asian history',
#     'url': 'https://openlibrary.org/subjects/asian_history'}]}}

# %% [markdown]
# ## Setting ISBN column as index

# %%
display(books_df.head(5))
books_df.columns
# Out:
#                                                title  \
# 1  Harry Potter and the Half-Blood Prince (Harry ...
# 2  Harry Potter and the Order of the Phoenix (Har...
# 3  Harry Potter and the Chamber of Secrets (Harry...
# 4  Harry Potter and the Prisoner of Azkaban (Harr...
# 5  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors         isbn13    num_pages  \
# 1  J.K. Rowling/Mary GrandPré  9780439785969          652
# 2  J.K. Rowling/Mary GrandPré  9780439358071          870
# 3                J.K. Rowling  9780439554893          352
# 4  J.K. Rowling/Mary GrandPré  9780439655484          435
# 5  J.K. Rowling/Mary GrandPré  9780439682589         2690
#
#          publication_date        publisher  \
# 1 2006-01-01 00:16:00.900  Scholastic Inc.
# 2 2004-01-01 00:01:00.900  Scholastic Inc.
# 3 2003-01-01 00:01:00.110       Scholastic
# 4 2004-01-01 00:01:00.500  Scholastic Inc.
# 5 2004-01-01 00:13:00.900       Scholastic
#
#                                            cover_url
# 1  https://covers.openlibrary.org/b/id/9326654-L.jpg
# 2  https://covers.openlibrary.org/b/id/12025650-L...
# 3  https://covers.openlibrary.org/b/id/10301720-L...
# 4  https://covers.openlibrary.org/b/id/8778528-L.jpg
# 5   https://covers.openlibrary.org/b/id/278981-L.jpg
# Index(['title', 'authors', 'isbn13', '  num_pages', 'publication_date',
#        'publisher', 'cover_url'],
#       dtype='object')

# %%
books_df.set_index("isbn13", inplace=True)

# %%
books_df
# Out:
#                                                            title  \
# isbn13
# 9780439785969  Harry Potter and the Half-Blood Prince (Harry ...
# 9780439358071  Harry Potter and the Order of the Phoenix (Har...
# 9780439554893  Harry Potter and the Chamber of Secrets (Harry...
# 9780439655484  Harry Potter and the Prisoner of Azkaban (Harr...
# 9780439682589  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                          ...
# 9781560254416   Expelled from Eden: A William T. Vollmann Reader
# 9780140110876                        You Bright and Risen Angels
# 9780140131963                    The Ice-Shirt (Seven Dreams #1)
# 9780060878825                                        Poor People
# 9788497646987                        Las aventuras de Tom Sawyer
#
#                                                          authors    num_pages  \
# isbn13
# 9780439785969                         J.K. Rowling/Mary GrandPré          652
# 9780439358071                         J.K. Rowling/Mary GrandPré          870
# 9780439554893                                       J.K. Rowling          352
# 9780439655484                         J.K. Rowling/Mary GrandPré          435
# 9780439682589                         J.K. Rowling/Mary GrandPré         2690
# ...                                                          ...          ...
# 9781560254416  William T. Vollmann/Larry McCaffery/Michael He...          512
# 9780140110876                                William T. Vollmann          635
# 9780140131963                                William T. Vollmann          415
# 9780060878825                                William T. Vollmann          434
# 9788497646987                                         Mark Twain          272
#
#                      publication_date        publisher  \
# isbn13
# 9780439785969 2006-01-01 00:16:00.900  Scholastic Inc.
# 9780439358071 2004-01-01 00:01:00.900  Scholastic Inc.
# 9780439554893 2003-01-01 00:01:00.110       Scholastic
# 9780439655484 2004-01-01 00:01:00.500  Scholastic Inc.
# 9780439682589 2004-01-01 00:13:00.900       Scholastic
# ...                               ...              ...
# 9781560254416 2004-01-01 00:21:00.120    Da Capo Press
# 9780140110876 1988-01-01 00:01:00.120    Penguin Books
# 9780140131963 1993-01-01 00:01:00.800    Penguin Books
# 9780060878825 2007-01-01 00:27:00.200             Ecco
# 9788497646987 2006-01-01 00:28:00.500    Edimat Libros
#
#                                                        cover_url
# isbn13
# 9780439785969  https://covers.openlibrary.org/b/id/9326654-L.jpg
# 9780439358071  https://covers.openlibrary.org/b/id/12025650-L...
# 9780439554893  https://covers.openlibrary.org/b/id/10301720-L...
# 9780439655484  https://covers.openlibrary.org/b/id/8778528-L.jpg
# 9780439682589   https://covers.openlibrary.org/b/id/278981-L.jpg
# ...                                                          ...
# 9781560254416                                               None
# 9780140110876                                               None
# 9780140131963                                               None
# 9780060878825                                               None
# 9788497646987                                               None
#
# [11123 rows x 6 columns]

# %% [markdown]
# ## Playing around with tqdm library

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /home/abellan/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (4.64.1)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %%time

from tqdm import tqdm

for group in tqdm(np.array_split(books_df.head(100), 5)): # 5 groups of 20 books
    books = fetch_books(list(group.index))
    
    for isbn_code, book in books.items():
        isbn = int(isbn_code.strip("ISBN:"))
        books_df.loc[isbn, "cover_url"] = book.get("cover", {}).get("large", "")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:11<00:00,  2.34s/it]
# CPU times: user 1.89 s, sys: 70.8 ms, total: 1.96 s
# Wall time: 11.9 s
